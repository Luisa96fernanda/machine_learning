# %% [markdown]
# # **Support Vector Regresion (SVR)**

# %% [markdown]
# ```SVR``` module documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html)

# %% [markdown]
# ## In Synthetic data

# %%
import numpy as np # Librería mateamtica
import matplotlib.pyplot as plt # plots

from sklearn.svm import SVR
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples = 500, n_features = 1, noise = 10, random_state = 1)
#convierte la funcion a exponencial
#y= (y*0.1)**2

_, ax = plt.subplots (figsize=(5,4))
ax.scatter( X , y , s=10, c = 'b')

# %%
#svr = SVR(kernel = "linear" )
#svr = SVR(kernel = "poly" )
svr = SVR(kernel = "rbf" )
svr.fit( X.reshape(-1,1), y )
# Out:
# SVR()

# %%
# Predecir la nueva muestra. Imprimir la prediccion
prediction = svr.predict(X.reshape(-1,1))
print (prediction.shape)
# Out:
# (500,)

# %%
# Draw real samples (blue) and predictions (red)
_, ax = plt.subplots (figsize = ( 5,4))
ax.scatter( X , y , s=10, color = 'blue')
ax.scatter ( X , prediction ,s=10, color = 'red')

print(svr.support_vectors_.min(),svr.support_vectors_.max())

#vectores de soporte esta malo
#ax.scatter(X, svr.support_vectors_, s=30, edgecolors='k', facecolors='none')
# Out:
# -2.79308500014654 3.0308571123720305

# %% [markdown]
# ## In real data

# %% [markdown]
# ```datasets``` module info [here](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.datasets)

# %%
import numpy as np
import matplotlib.pyplot as plt # plots

from sklearn.svm import SVR
from sklearn.datasets import load_diabetes

# %%
# Cargar la base de datos Diabetes
diabetes_X, diabetes_y = load_diabetes(return_X_y=True)
print( X.shape , y.shape)
# Out:
# (500, 1) (500,)

# %%
# Use only one feature
diabetes_X = load_diabetes()
diabetes_X = diabetes_X.data[:,0:1]
print(diabetes_X.shape, diabetes_y.shape)
# Out:
# (442, 1) (442,)

# %%
# Create an instance of SVM and fit the data.
svr = SVR(kernel = "linear" )
svr.fit( diabetes_X.reshape(-1,1), diabetes_y )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4d4b36f6106e> in <cell line: 3>()
#       1 # Create an instance of SVM and fit the data.
#       2 svr = SVR(kernel = "linear" )
# ----> 3 svr.fit( diabetes_X.reshape(-1,1), diabetes_y )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     188             check_consistent_length(X, y)
#     189         else:
# --> 190             X, y = self._validate_data(
#     191                 X,
#     192                 y,
#
# ...

# %%
# Predecir la nueva muestra. Imprimir la prediccion
prediction = svr.predict(diabetes_X.reshape(-1,1))
print (prediction.shape)
# Out:
# (442,)

# %%
# Draw real samples (blue) and predictions (red)
_, ax = plt.subplots (figsize = ( 5,4))
ax.scatter( diabetes_X , diabetes_y , s=10, color = 'blue')
ax.scatter ( diabetes_X , prediction ,s=10, color = 'red')

print(svr.support_vectors_.min(),svr.support_vectors_.max())

#vectores de soporte esta malo
#ax.scatter(X, svr.support_vectors_, s=30, edgecolors='k', facecolors='none')
# Out:
# -0.1072256316073538 0.11072667545381144
